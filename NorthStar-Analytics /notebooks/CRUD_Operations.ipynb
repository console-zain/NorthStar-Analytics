# %% [markdown]
# <a href="https://colab.research.google.com/github/console-zain/NorthStar-Analytics/blob/main/NorthStar-Analytics%20/notebooks/CRUD_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CREATE

# %%
collection.insert_one({
    "order_id": "TEST100",
    "delivery": {
        "delay_flag": False,
        "delivery_time_hours": 1.5
    }
})

# %% [markdown]
# # READ

# %%
collection.find_one({"order_id": "TEST100"})

# %% [markdown]
# # UPDATE

# %%
collection.update_one(
    {"order_id": "TEST100"},
    {"$set": {"delivery.delay_flag": True}}
)

# %% [markdown]
# # DELETE

# %%
collection.delete_one({"order_id": "TEST100"})
